# %% [markdown]
# <a href="https://colab.research.google.com/github/nabilnehme/AAI614_Nehme/blob/main/Week3/Nabil_Nehme_FluWatch_PE2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = "https://www.canada.ca/en/public-health/services/surveillance/respiratory-virus-detections-canada/2018-2019/respiratory-virus-detections-isolations-week-01-ending-january-5-2019.html"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Locate Table 2 and process it into a DataFrame
table = soup.find_all("table")[1]
rows = []

for row in table.find_all("tr")[1:]:  # Skip header
    cols = [col.get_text(strip=True) for col in row.find_all("td")]
    rows.append(cols)

# Convert table data to DataFrame as before
columns = ["Reporting Laboratory", "Flu Tested", "A(H1N1)pdm09 Positive", "A(H3) Positive", "A(UnS) Positive", "Total Flu A Positive", "Total Flu B Positive", "RSV Tested", "RSV Positive", "PIV Tested", "PIV 1 Positive", "PIV 2 Positive", "PIV 3 Positive", "PIV 4 Positive", "Other PIV Positive", "Adeno Tested", "Adeno Positive", "hMPV Tested", "hMPV Positive", "Entero/Rhino Tested", "Entero/Rhino Positive", "Coron Tested", "Coron Positive"]

df = pd.DataFrame(rows, columns=columns)

# Fill NaN values with an empty string to avoid errors with .isdigit()
df['Flu Tested'] = df['Flu Tested'].fillna("")

# Filter out rows with text data instead of numbers
df = df[df['Flu Tested'].str.isdigit()]

df
# Out:
#                    Reporting Laboratory Flu Tested A(H1N1)pdm09 Positive  \
# 0                          Newfoundland       1299                     1
# 1                  Prince Edward Island        307                    38
# 2                           Nova Scotia        864                     0
# 3                         New Brunswick       4271                    42
# 4                              Atlantic       6741                    81
# 5                    Région    Nord-Est       3551                     0
# 6           Québec-Chaudière-Appalaches       5028                     0
# 7                      Centre-du-Québec       5435                     0
# 8                        Montréal-Laval      16318                     0
# 9                       Ouest du Québec       4775                     0
# 10                           Montérégie       3288                     0
# 11                   Province of Québec      38395                     0
# ...
